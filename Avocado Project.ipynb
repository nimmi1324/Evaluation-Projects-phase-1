# %% [markdown]
# # Avocado Project

# %% [markdown]
# # Project Description
#
#
#
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
# Some relevant columns in the dataset:
# •	Date - The date of the observation
# •	AveragePrice - the average price of a single avocado
# •	type - conventional or organic
# •	year - the year
# •	Region - the city or region of the observation
# •	Total Volume - Total number of avocados sold
# •	4046 - Total number of avocados with PLU 4046 sold
# •	4225 - Total number of avocados with PLU 4225 sold
# •	4770 - Total number of avocados with PLU 4770 sold
#
# Inspiration /Label
# The dataset can be seen in two angles to find the region and find the average price .
# Task: One of Classification and other of Regression
# Do both tasks in the same .ipynb file and submit at single file.

# %% [markdown]
# Dataset Link-https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/avocado.csv.zip

# %% [markdown]
# # import all libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
df=pd.read_csv('C:/Users/HP/Desktop/Learning-2023/Data-Science-ML-Capstone-Projects/avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 16463         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16464         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16465         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16466         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16467         NaN  NaN           NaN           NaN   NaN   NaN   NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 16463         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16464         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16465         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16466         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16467         NaN         NaN         NaN          NaN  NaN   NaN    NaN

# %%
df.shape
# Out:
# (16468, 14)

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %% [markdown]
# Will show you null count for each column, but will not count Zeros(0) as null

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# This will print the names of all columns.

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# Lets check our data head again to make sure that the Feature Unnamed:0 is removed

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %% [markdown]
# Earlier in info we have seen that Date is Object type not the date type. We have to change its type to date type.

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].apply(lambda x:x.month)
df['Day']=df['Date'].apply(lambda x:x.day)

# %% [markdown]
# Lets check the head to see what we have done now.

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region  Month   Day
# 0  Albany   12.0  27.0
# 1  Albany   12.0  20.0
# 2  Albany   12.0  13.0
# ...

# %% [markdown]
# # Data visualization

# %%
sns.set(font_scale=1.5) 
from scipy.stats import norm
fig, ax = plt.subplots(figsize=(15, 9))
sns.distplot(a=df.AveragePrice, kde=False, fit=norm)
# Out:
# <Axes: xlabel='AveragePrice'>

# %% [markdown]
# Average Price distribution shows that for most cases price of avocado is between 1.1, 1.4.
# Let's look at average price of conventional vs. organic.

# %%
plt.figure(figsize=(16,12))
sns.lineplot(x="Month", y="AveragePrice", hue='type', data=df)
plt.show()

# %% [markdown]
# hike between months 8 – 10 for both Conventional and Organic type of Avocados prices

# %%
df.plot(kind='box',subplots=True,layout=(6,4))
# Out:
# AveragePrice        Axes(0.125,0.77;0.168478x0.11)
# Total Volume     Axes(0.327174,0.77;0.168478x0.11)
# 4046             Axes(0.529348,0.77;0.168478x0.11)
# 4225             Axes(0.731522,0.77;0.168478x0.11)
# 4770               Axes(0.125,0.638;0.168478x0.11)
# Total Bags      Axes(0.327174,0.638;0.168478x0.11)
# Small Bags      Axes(0.529348,0.638;0.168478x0.11)
# Large Bags      Axes(0.731522,0.638;0.168478x0.11)
# XLarge Bags        Axes(0.125,0.506;0.168478x0.11)
# year            Axes(0.327174,0.506;0.168478x0.11)
# Month           Axes(0.529348,0.506;0.168478x0.11)
# Day             Axes(0.731522,0.506;0.168478x0.11)
# dtype: object

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# finding out if their any null value graphically.

# %%
dfcor=df.corr()
dfcor
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
# Month             0.060642     -0.055212 -0.053007 -0.058429 -0.055079
# Day               0.092589     -0.034857 -0.031806 -0.044008 -0.021318
#
# ...

# %% [markdown]
# finding out the correlation between each variable in the dataset

# %%
plt.figure(figsize=(24,10))
ax=sns.barplot(x=sorted_data.region_list,y=sorted_data.average_price)

plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price of Avocado According to Region')
# Out:
# Text(0.5, 1.0, 'Average Price of Avocado According to Region')

# %%
byDate=df.groupby('Date').mean()
plt.figure(figsize=(12,8))
byDate['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %% [markdown]
# This also shows there was a huge hike in prices after July 2017 and before Jan 2018. This was also confirmed in earlier graph too.

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# As we can from the heatmap above, all the Features are not correleted with the Average Price column, instead most of them are correlated with each other. So now I am bit worried because that will not help us get a good model.

# %% [markdown]
# # Feature Engineering for Model building

# %%
df['region'].nunique()
# Out:
# 51

# %%
df['type'].nunique()
# Out:
# 1

# %% [markdown]
# we have 54 regions and 2 unique types, so it's going to be easy to to transform the type feature to dummies, but for the region its going to be a bit complex, so I decided to drop the entire column.

# %%
df_final=pd.get_dummies(df.drop(['region','Date'],axis=1),drop_first=True)

# %%
df_final.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags    year  Month   Day
# 0     8603.62       93.25          0.0  2015.0   12.0  27.0
# 1     9408.07       97.49          0.0  2015.0   12.0  20.0
# 2     8042.21      103.14          0.0  2015.0   12.0  13.0
# 3     5677.40      133.76          0.0  2015.0    6.0  12.0
# 4     5986.26      197.69          0.0  2015.0   11.0  29.0

# %%
df_final.tail()
# Out:
#        AveragePrice  Total Volume  4046  4225  4770  Total Bags  Small Bags  \
# 16463           NaN           NaN   NaN   NaN   NaN         NaN         NaN
# 16464           NaN           NaN   NaN   NaN   NaN         NaN         NaN
# 16465           NaN           NaN   NaN   NaN   NaN         NaN         NaN
# 16466           NaN           NaN   NaN   NaN   NaN         NaN         NaN
# 16467           NaN           NaN   NaN   NaN   NaN         NaN         NaN
#
#        Large Bags  XLarge Bags  year  Month  Day
# 16463         NaN          NaN   NaN    NaN  NaN
# 16464         NaN          NaN   NaN    NaN  NaN
# 16465         NaN          NaN   NaN    NaN  NaN
# 16466         NaN          NaN   NaN    NaN  NaN
# 16467         NaN          NaN   NaN    NaN  NaN
